# %% [markdown]
# <a href="https://colab.research.google.com/github/bdunn20/book_code/blob/main/pandas_1.X_cookbook/Ch8_Index_Alignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Examining the Index object

# %%
import pandas as pd
import numpy as np

# %%
college = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/college.csv')

columns = college.columns
columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
# us .values attribute to access the underlying Numpy array
columns.values
# Out:
# array(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY',
#        'RELAFFIL', 'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS',
#        'UGDS_WHITE', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN',
#        'UGDS_NHPI', 'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF',
#        'CURROPER', 'PCTPELL', 'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10',
#        'GRAD_DEBT_MDN_SUPP'], dtype=object)

# %%
# select items from the index by position w/ a scalar, list or slice
columns[5]
# Out:
# 'WOMENONLY'

# %%
columns[[1, 8, 10]]
# Out:
# Index(['CITY', 'SATMTMID', 'UGDS'], dtype='object')

# %%
columns[-7:-4]
# Out:
# Index(['PPTUG_EF', 'CURROPER', 'PCTPELL'], dtype='object')

# %%
# indexes share many of the same methods as Series and DataFrames
columns.min(), columns.max(), columns.isnull().sum()
# Out:
# ('CITY', 'WOMENONLY', 0)

# %%
# use basic arithmetic & comparison operators on Index objects
columns + "_A"
# Out:
# Index(['INSTNM_A', 'CITY_A', 'STABBR_A', 'HBCU_A', 'MENONLY_A', 'WOMENONLY_A',
#        'RELAFFIL_A', 'SATVRMID_A', 'SATMTMID_A', 'DISTANCEONLY_A', 'UGDS_A',
#        'UGDS_WHITE_A', 'UGDS_BLACK_A', 'UGDS_HISP_A', 'UGDS_ASIAN_A',
#        'UGDS_AIAN_A', 'UGDS_NHPI_A', 'UGDS_2MOR_A', 'UGDS_NRA_A',
#        'UGDS_UNKN_A', 'PPTUG_EF_A', 'CURROPER_A', 'PCTPELL_A', 'PCTFLOAN_A',
#        'UG25ABV_A', 'MD_EARN_WNE_P10_A', 'GRAD_DEBT_MDN_SUPP_A'],
#       dtype='object')

# %%
columns > "G"
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True])

# %%
# Indexes are immutable objects
columns[1] = "city"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-1c2c2d8355b8> in <cell line: 2>()
#       1 # Indexes are immutable objects
# ----> 2 columns[1] = "city"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5300     @final
#    5301     def __setitem__(self, key, value):
# -> 5302         raise TypeError("Index does not support mutable operations")
#    5303
#    5304     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
# Indexes support the set operations (union, intersection, difference, symmetric diff)
c1 = columns[:4]
c1
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU'], dtype='object')

# %%
c2 = columns[2:6]
c2
# Out:
# Index(['STABBR', 'HBCU', 'MENONLY', 'WOMENONLY'], dtype='object')

# %%
c1.union(c2) # same as 'c1 | c2'
# Out:
# Index(['CITY', 'HBCU', 'INSTNM', 'MENONLY', 'STABBR', 'WOMENONLY'], dtype='object')

# %% [markdown]
# ### Producing Cartesian products

# %%
# construct two Series that have indexes that are different but contain some of the same values
s1 = pd.Series(index=list("aaab"), data=np.arange(4))
s1
# Out:
# a    0
# a    1
# a    2
# b    3
# dtype: int64

# %%
s2 = pd.Series(index=list("cababb"), data=np.arange(6))
s2
# Out:
# c    0
# a    1
# b    2
# a    3
# b    4
# b    5
# dtype: int64

# %%
# add the two Series together to produce a Cartesian product
# for each a index value in s1, we add every a in s2
s1 + s2
# Out:
# a    1.0
# a    3.0
# a    2.0
# a    4.0
# a    3.0
# a    5.0
# b    5.0
# b    7.0
# b    8.0
# c    NaN
# dtype: float64

# %% [markdown]
# ### Exploding Indexes
#
# *This recipe is basically a what not do to!*

# %%
employee = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/employee.csv?_sm_au_=iVVWLDQPlJVWHWMFBQvGvK7jj80tt', index_col="RACE")

employee.head()
# Out:
#                  UNIQUE_ID               POSITION_TITLE  \
# RACE
# Hispanic/Latino          0  ASSISTANT DIRECTOR (EX LVL)
# Hispanic/Latino          1            LIBRARY ASSISTANT
# White                    2               POLICE OFFICER
# White                    3            ENGINEER/OPERATOR
# White                    4                  ELECTRICIAN
#
#                                     DEPARTMENT  BASE_SALARY EMPLOYMENT_TYPE  \
# RACE
# Hispanic/Latino    Municipal Courts Department     121862.0       Full Time
# Hispanic/Latino                        Library      26125.0       Full Time
# White            Houston Police Department-HPD      45279.0       Full Time
# White            Houston Fire Department (HFD)      63166.0       Full Time
# White              General Services Department      56347.0       Full Time
#
#                  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# RACE
# Hispanic/Latino  Female            Active  2006-06-12  2012-10-13
# Hispanic/Latino  Female            Active  2000-07-19  2010-09-18
# White              Male            Active  2015-02-03  2015-02-03
# White              Male            Active  1982-02-08  1991-05-25
# White              Male            Active  1989-06-19  1994-10-22

# %%
# select the BASE_SALARY column as two different Series
salary1 = employee["BASE_SALARY"]
salary2 = employee["BASE_SALARY"]

# check to see whether this operation created two new objects
salary1 is salary2
# Out:
# True

# %%
# use the .copy method to ensure you have a brand new copy of the data
salary2 = employee["BASE_SALARY"].copy()
salary1 is salary2
# Out:
# False

# %%
# change the order of the index by sorting it
salary1 = salary1.sort_index()
salary1.head()
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    98536.0
# American Indian or Alaskan Native        NaN
# American Indian or Alaskan Native    55461.0
# Name: BASE_SALARY, dtype: float64

# %%
salary2.head()
# Out:
# RACE
# Hispanic/Latino    121862.0
# Hispanic/Latino     26125.0
# White               45279.0
# White               63166.0
# White               56347.0
# Name: BASE_SALARY, dtype: float64

# %%
# add the Series together
salary_add = salary1 + salary2
salary_add.head()
# Out:
# RACE
# American Indian or Alaskan Native    138702.0
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native    176891.0
# American Indian or Alaskan Native    159594.0
# American Indian or Alaskan Native    127734.0
# Name: BASE_SALARY, dtype: float64

# %%
# add salary1 to itself and output the lengths of each Series
salary_add1 = salary1 + salary1
len(salary1), len(salary2), len(salary_add), len(salary_add1)
# Out:
# (2000, 2000, 1175424, 2000)

# %% [markdown]
# ### Filling values with unequal indexes

# %%
# add together multiple Series with unequal (but unique) indexes
# using the .add method w/ the fill_value parameter to ensure no missing values
baseball_14 = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/baseball14.csv?_sm_au_=iVVWLDQPlJVWHWMFBQvGvK7jj80tt', index_col="playerID")
baseball_15 = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/baseball15.csv?_sm_au_=iVVWPPnJffntZBk3BQvGvK7jj80tt', index_col="playerID")
baseball_16 = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/baseball16.csv?_sm_au_=iVVWPPnJffntZBk3BQvGvK7jj80tt', index_col="playerID")

baseball_14.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...   RBI  \
# playerID                                                         ...
# altuvjo01    2014      1    HOU   AL  158  660  85  225  47   3  ...  59.0
# cartech02    2014      1    HOU   AL  145  507  68  115  21   1  ...  88.0
# castrja01    2014      1    HOU   AL  126  465  43  103  21   2  ...  56.0
# corpoca01    2014      1    HOU   AL   55  170  22   40   6   0  ...  19.0
# dominma01    2014      1    HOU   AL  157  564  51  121  17   0  ...  57.0
#
#              SB   CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  56.0  9.0  36   53.0  7.0  5.0  1.0  5.0  20.0
# cartech02   5.0  2.0  56  182.0  6.0  5.0  0.0  4.0  12.0
# castrja01   1.0  0.0  34  151.0  1.0  9.0  1.0  3.0  11.0
# corpoca01   0.0  0.0  14   37.0  0.0  3.0  1.0  2.0   3.0
# dominma01   0.0  1.0  29  125.0  2.0  5.0  2.0  7.0  23.0
#
# [5 rows x 21 columns]

# %%
# use the .difference method on the index to discover which index labels are in baseball_14 and not in baseball_15
baseball_14.index.difference(baseball_15.index)
# Out:
# Index(['corpoca01', 'dominma01', 'fowlede01', 'grossro01', 'guzmaje01',
#        'hoeslj01', 'krausma01', 'preslal01', 'singljo02'],
#       dtype='object', name='playerID')

# %%
baseball_15.index.difference(baseball_14.index)
# Out:
# Index(['congeha01', 'correca01', 'gattiev01', 'gomezca01', 'lowrije01',
#        'rasmuco01', 'tuckepr01', 'valbulu01'],
#       dtype='object', name='playerID')

# %%
# how many hits did each player have in total over the three-year period?
hits_14 = baseball_14["H"]
hits_15 = baseball_15["H"]
hits_16 = baseball_16["H"]
hits_14.head()
# Out:
# playerID
# altuvjo01    225
# cartech02    115
# castrja01    103
# corpoca01     40
# dominma01    121
# Name: H, dtype: int64

# %%
# add together the 14 & 15 Series
(hits_14 + hits_15).head()
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01      NaN
# corpoca01      NaN
# Name: H, dtype: float64

# %%
# use the add method to avoid the above NaN where players without any hits in a given season throw an error
hits_14.add(hits_15, fill_value=0).head()
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01     46.0
# corpoca01     40.0
# Name: H, dtype: float64

# %%
# add the 2016 Series
hits_total = hits_14.add(hits_15, fill_value=0).add(hits_16, fill_value=0)
hits_total.head()
# Out:
# playerID
# altuvjo01    641.0
# bregmal01     53.0
# cartech02    193.0
# castrja01    243.0
# congeha01     46.0
# Name: H, dtype: float64

# %%
# check for missing values
hits_total.hasnans
# Out:
# False

# %%
# add Series w/ only a single index together
df_14 = baseball_14[["G", "AB", "R", "H"]]
df_14.head()
# Out:
#              G   AB   R    H
# playerID
# altuvjo01  158  660  85  225
# cartech02  145  507  68  115
# castrja01  126  465  43  103
# corpoca01   55  170  22   40
# dominma01  157  564  51  121

# %%
# select a few of the same and a few diff columns from 2015 data
df_15 = baseball_15[["AB", "R", "H", "HR"]]
df_15.head()
# Out:
#             AB   R    H  HR
# playerID
# altuvjo01  638  86  200  15
# cartech02  391  50   78  24
# castrja01  337  38   71  11
# congeha01  201  25   46  11
# correca01  387  52  108  22

# %%
# adding the df together creates missing values wherever rows or column labels cannot align
# use the .style attribute and call .highlight_null
(df_14 + df_15).head(10).style.highlight_null('yellow')
# Out:
# <style type="text/css">
# #T_78c89_row0_col1, #T_78c89_row0_col3, #T_78c89_row1_col1, #T_78c89_row1_col3, #T_78c89_row2_col1, #T_78c89_row2_col3, #T_78c89_row3_col0, #T_78c89_row3_col1, #T_78c89_row3_col2, #T_78c89_row3_col3, #T_78c89_row3_col4, #T_78c89_row4_col0, #T_78c89_row4_col1, #T_78c89_row4_col2, #T_78c89_row4_col3, #T_78c89_row4_col4, #T_78c89_row5_col0, #T_78c89_row5_col1, #T_78c89_row5_col2, #T_78c89_row5_col3, #T_78c89_row5_col4, #T_78c89_row6_col0, #T_78c89_row6_col1, #T_78c89_row6_col2, #T_78c89_row6_col3, #T_78c89_row6_col4, #T_78c89_row7_col0, #T_78c89_row7_col1, #T_78c89_row7_col2, #T_78c89_row7_col3, #T_78c89_row7_col4, #T_78c89_row8_col0, #T_78c89_row8_col1, #T_78c89_row8_col2, #T_78c89_row8_col3, #T_78c89_row8_col4, #T_78c89_row9_col0, #T_78c89_row9_col1, #T_78c89_row9_col2, #T_78c89_row9_col3, #T_78c89_row9_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_78c89" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78c89_level0_col0" class="col_heading level0 col0" >AB</th>
#       <th id="T_78c89_level0_col1" class="col_heading level0 col1" >G</th>
#       <th id="T_78c89_level0_col2" class="col_heading level0 col2" >H</th>
#       <th id="T_78c89_level0_col3" class="col_heading level0 col3" >HR</th>
#       <th id="T_78c89_level0_col4" class="col_heading level0 col4" >R</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >playerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78c89_level0_row0" class="row_heading level0 row0" >altuvjo01</th>
#       <td id="T_78c89_row0_col0" class="data row0 col0" >1298.000000</td>
#       <td id="T_78c89_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_78c89_row0_col2" class="data row0 col2" >425.000000</td>
#       <td id="T_78c89_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_78c89_row0_col4" class="data row0 col4" >171.000000</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row1" class="row_heading level0 row1" >cartech02</th>
#       <td id="T_78c89_row1_col0" class="data row1 col0" >898.000000</td>
#       <td id="T_78c89_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_78c89_row1_col2" class="data row1 col2" >193.000000</td>
#       <td id="T_78c89_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_78c89_row1_col4" class="data row1 col4" >118.000000</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row2" class="row_heading level0 row2" >castrja01</th>
#       <td id="T_78c89_row2_col0" class="data row2 col0" >802.000000</td>
#       <td id="T_78c89_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_78c89_row2_col2" class="data row2 col2" >174.000000</td>
#       <td id="T_78c89_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_78c89_row2_col4" class="data row2 col4" >81.000000</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row3" class="row_heading level0 row3" >congeha01</th>
#       <td id="T_78c89_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_78c89_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_78c89_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_78c89_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_78c89_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row4" class="row_heading level0 row4" >corpoca01</th>
#       <td id="T_78c89_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_78c89_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_78c89_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_78c89_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_78c89_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row5" class="row_heading level0 row5" >correca01</th>
#       <td id="T_78c89_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_78c89_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_78c89_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_78c89_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_78c89_row5_col4" class="data row5 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row6" class="row_heading level0 row6" >dominma01</th>
#       <td id="T_78c89_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_78c89_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_78c89_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_78c89_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_78c89_row6_col4" class="data row6 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row7" class="row_heading level0 row7" >fowlede01</th>
#       <td id="T_78c89_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_78c89_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_78c89_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_78c89_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_78c89_row7_col4" class="data row7 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row8" class="row_heading level0 row8" >gattiev01</th>
#       <td id="T_78c89_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_78c89_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_78c89_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_78c89_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_78c89_row8_col4" class="data row8 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_78c89_level0_row9" class="row_heading level0 row9" >gomezca01</th>
#       <td id="T_78c89_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_78c89_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_78c89_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_78c89_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_78c89_row9_col4" class="data row9 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Adding columns from different DataFrames

# %%
dept_sal = employee[["DEPARTMENT", "BASE_SALARY"]]

# %%
# sort by salary within each dept
dept_sal = dept_sal.sort_values(["DEPARTMENT", "BASE_SALARY"], ascending=[True, False])

# %%
# use .drop_duplicates method to keep first row of each DEPARTMENT
max_dept_sal = dept_sal.drop_duplicates(subset="DEPARTMENT")
max_dept_sal.head()
# Out:
#                                              DEPARTMENT  BASE_SALARY
# RACE
# White                        Admn. & Regulatory Affairs     140416.0
# Hispanic/Latino                City Controller's Office      64251.0
# Black or African American                  City Council     100000.0
# Hispanic/Latino            Convention and Entertainment      38397.0
# Black or African American   Dept of Neighborhoods (DON)      89221.0

# %%
# put the DEPARTMENT column into the index for each df
max_dept_sal = max_dept_sal.set_index("DEPARTMENT")
employee2 = employee.set_index("DEPARTMENT")

# %%
employee2 = employee2.assign(MAX_DEPT_SALARY=max_dept_sal["BASE_SALARY"])
employee2
# Out:
#                                UNIQUE_ID               POSITION_TITLE  \
# DEPARTMENT
# Municipal Courts Department            0  ASSISTANT DIRECTOR (EX LVL)
# Library                                1            LIBRARY ASSISTANT
# Houston Police Department-HPD          2               POLICE OFFICER
# Houston Fire Department (HFD)          3            ENGINEER/OPERATOR
# General Services Department            4                  ELECTRICIAN
# ...                                  ...                          ...
# Houston Police Department-HPD       1995               POLICE OFFICER
# Houston Fire Department (HFD)       1996       COMMUNICATIONS CAPTAIN
# Houston Police Department-HPD       1997               POLICE OFFICER
# Houston Police Department-HPD       1998               POLICE OFFICER
# Houston Fire Department (HFD)       1999                 FIRE FIGHTER
#
#                                BASE_SALARY EMPLOYMENT_TYPE  GENDER  \
# DEPARTMENT
# Municipal Courts Department       121862.0       Full Time  Female
# Library                            26125.0       Full Time  Female
# Houston Police Department-HPD      45279.0       Full Time    Male
# Houston Fire Department (HFD)      63166.0       Full Time    Male
# General Services Department        56347.0       Full Time    Male
# ...                                    ...             ...     ...
# Houston Police Department-HPD      43443.0       Full Time    Male
# Houston Fire Department (HFD)      66523.0       Full Time    Male
# Houston Police Department-HPD      43443.0       Full Time    Male
# Houston Police Department-HPD      55461.0       Full Time    Male
# Houston Fire Department (HFD)      51194.0       Full Time    Male
#
#                               EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE  \
# DEPARTMENT
# Municipal Courts Department              Active  2006-06-12  2012-10-13
# Library                                  Active  2000-07-19  2010-09-18
# Houston Police Department-HPD            Active  2015-02-03  2015-02-03
# Houston Fire Department (HFD)            Active  1982-02-08  1991-05-25
# General Services Department              Active  1989-06-19  1994-10-22
# ...                                         ...         ...         ...
# Houston Police Department-HPD            Active  2014-06-09  2015-06-09
# Houston Fire Department (HFD)            Active  2003-09-02  2013-10-06
# Houston Police Department-HPD            Active  2014-10-13  2015-10-13
# Houston Police Department-HPD            Active  2009-01-20  2011-07-02
# Houston Fire Department (HFD)            Active  2009-01-12  2010-07-12
#
#                                MAX_DEPT_SL  MAX_DEPT_SALARY
# DEPARTMENT
# Municipal Courts Department       121862.0         121862.0
# Library                           107763.0         107763.0
# Houston Police Department-HPD     199596.0         199596.0
# Houston Fire Department (HFD)     210588.0         210588.0
# General Services Department        89194.0          89194.0
# ...                                    ...              ...
# Houston Police Department-HPD     199596.0         199596.0
# Houston Fire Department (HFD)     210588.0         210588.0
# Houston Police Department-HPD     199596.0         199596.0
# Houston Police Department-HPD     199596.0         199596.0
# Houston Fire Department (HFD)     210588.0         210588.0
#
# [2000 rows x 10 columns]

# %%
# validate our resluts with the query method to check whether there exist
# any rows where BASE_SALARY is > MAX_DEPT_SALARY
employee2.query("BASE_SALARY > MAX_DEPT_SALARY")
# Out:
# Empty DataFrame
# Columns: [UNIQUE_ID, POSITION_TITLE, BASE_SALARY, EMPLOYMENT_TYPE, GENDER, EMPLOYMENT_STATUS, HIRE_DATE, JOB_DATE, MAX_DEPT_SL, MAX_DEPT_SALARY]
# Index: []

# %%
# alternative method using .groupby combined w/ .transform
max_sal = employee.groupby("DEPARTMENT").BASE_SALARY.transform("max")

# %%
employee.assign(MAX_DEPT_SAL=max_sal)
# Out:
#                            UNIQUE_ID               POSITION_TITLE  \
# RACE
# Hispanic/Latino                    0  ASSISTANT DIRECTOR (EX LVL)
# Hispanic/Latino                    1            LIBRARY ASSISTANT
# White                              2               POLICE OFFICER
# White                              3            ENGINEER/OPERATOR
# White                              4                  ELECTRICIAN
# ...                              ...                          ...
# White                           1995               POLICE OFFICER
# Black or African American       1996       COMMUNICATIONS CAPTAIN
# White                           1997               POLICE OFFICER
# Asian/Pacific Islander          1998               POLICE OFFICER
# Hispanic/Latino                 1999                 FIRE FIGHTER
#
#                                               DEPARTMENT  BASE_SALARY  \
# RACE
# Hispanic/Latino              Municipal Courts Department     121862.0
# Hispanic/Latino                                  Library      26125.0
# White                      Houston Police Department-HPD      45279.0
# White                      Houston Fire Department (HFD)      63166.0
# White                        General Services Department      56347.0
# ...                                                  ...          ...
# White                      Houston Police Department-HPD      43443.0
# Black or African American  Houston Fire Department (HFD)      66523.0
# White                      Houston Police Department-HPD      43443.0
# Asian/Pacific Islander     Houston Police Department-HPD      55461.0
# Hispanic/Latino            Houston Fire Department (HFD)      51194.0
#
#                           EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# RACE
# Hispanic/Latino                 Full Time  Female            Active
# Hispanic/Latino                 Full Time  Female            Active
# White                           Full Time    Male            Active
# White                           Full Time    Male            Active
# White                           Full Time    Male            Active
# ...                                   ...     ...               ...
# White                           Full Time    Male            Active
# Black or African American       Full Time    Male            Active
# White                           Full Time    Male            Active
# Asian/Pacific Islander          Full Time    Male            Active
# Hispanic/Latino                 Full Time    Male            Active
#
#                             HIRE_DATE    JOB_DATE  MAX_DEPT_SAL
# RACE
# Hispanic/Latino            2006-06-12  2012-10-13      121862.0
# Hispanic/Latino            2000-07-19  2010-09-18      107763.0
# White                      2015-02-03  2015-02-03      199596.0
# White                      1982-02-08  1991-05-25      210588.0
# White                      1989-06-19  1994-10-22       89194.0
# ...                               ...         ...           ...
# White                      2014-06-09  2015-06-09      199596.0
# Black or African American  2003-09-02  2013-10-06      210588.0
# White                      2014-10-13  2015-10-13      199596.0
# Asian/Pacific Islander     2009-01-20  2011-07-02      199596.0
# Hispanic/Latino            2009-01-12  2010-07-12      210588.0
#
# [2000 rows x 10 columns]

# %% [markdown]
# ### Highlighting the maxiumu value from each column

# %%
college = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/college.csv', index_col="INSTNM")
college.dtypes
# Out:
# CITY                   object
# STABBR                 object
# HBCU                  float64
# MENONLY               float64
# WOMENONLY             float64
# RELAFFIL                int64
# SATVRMID              float64
# SATMTMID              float64
# DISTANCEONLY          float64
# UGDS                  float64
# UGDS_WHITE            float64
# UGDS_BLACK            float64
# UGDS_HISP             float64
# UGDS_ASIAN            float64
# UGDS_AIAN             float64
# UGDS_NHPI             float64
# UGDS_2MOR             float64
# UGDS_NRA              float64
# UGDS_UNKN             float64
# PPTUG_EF              float64
# CURROPER                int64
# PCTPELL               float64
# PCTFLOAN              float64
# UG25ABV               float64
# MD_EARN_WNE_P10        object
# GRAD_DEBT_MDN_SUPP     object
# dtype: object

# %%
# all cols besides CITY and STABBR appear to be numeric
# MD_EARN_WNE_P10 & GRAD_DEBT_MDN_SUPP are of object type and also not numeric
# sample these columns to get a better idea
college.MD_EARN_WNE_P10.sample(10, random_state=42)
# Out:
# INSTNM
# Career Point College                                            20700
# Ner Israel Rabbinical College                       PrivacySuppressed
# Reflections Academy of Beauty                                     NaN
# Capital Area Technical College                                  26400
# West Virginia University Institute of Technology                43400
# Mid-State Technical College                                     32000
# Strayer University-Huntsville Campus                            49200
# National Aviation Academy of Tampa Bay                          45000
# University of California-Santa Cruz                             43000
# Lexington Theological Seminary                                    NaN
# Name: MD_EARN_WNE_P10, dtype: object

# %%
college.GRAD_DEBT_MDN_SUPP.sample(10, random_state=42)
# Out:
# INSTNM
# Career Point College                                            14977
# Ner Israel Rabbinical College                       PrivacySuppressed
# Reflections Academy of Beauty                       PrivacySuppressed
# Capital Area Technical College                      PrivacySuppressed
# West Virginia University Institute of Technology                23969
# Mid-State Technical College                                      8025
# Strayer University-Huntsville Campus                          36173.5
# National Aviation Academy of Tampa Bay                          22778
# University of California-Santa Cruz                             19884
# Lexington Theological Seminary                      PrivacySuppressed
# Name: GRAD_DEBT_MDN_SUPP, dtype: object

# %%
# values are strings but we'd prefer them to be numeric
# use .value_counts to determine any characters which caused non-numeric data type
college.MD_EARN_WNE_P10.value_counts()
# Out:
# PrivacySuppressed    822
# 38800                151
# 21500                 97
# 49200                 78
# 27400                 46
#                     ...
# 84000                  1
# 66900                  1
# 52800                  1
# 67800                  1
# 186500                 1
# Name: MD_EARN_WNE_P10, Length: 598, dtype: int64

# %%
set(college.MD_EARN_WNE_P10.apply(type))
# Out:
# {float, str}

# %%
college.GRAD_DEBT_MDN_SUPP.value_counts()
# Out:
# PrivacySuppressed    1510
# 9500                  514
# 27000                 306
# 25827.5               136
# 25000                 124
#                      ...
# 9604                    1
# 19262                   1
# 8099                    1
# 8050                    1
# 11061                   1
# Name: GRAD_DEBT_MDN_SUPP, Length: 2038, dtype: int64

# %%
# force these columns to numeric data type using .to_numeric
# using errors='coerce' parameter converts problematic values to NaN
cols = ["MD_EARN_WNE_P10", "GRAD_DEBT_MDN_SUPP"]
for col in cols:
  college[col] = pd.to_numeric(college[col], errors='coerce')

# %%
college.dtypes.loc[cols]
# Out:
# MD_EARN_WNE_P10       float64
# GRAD_DEBT_MDN_SUPP    float64
# dtype: object

# %%
# use .select_dtypes method to filter only numeric columns
# this will exclude STABBR and CITY columns, where max value doesn't make sense
college_n = college.select_dtypes("number")
college_n.head()
# Out:
#                                      HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Alabama A & M University              1.0      0.0        0.0         0
# University of Alabama at Birmingham   0.0      0.0        0.0         0
# Amridge University                    0.0      0.0        0.0         1
# University of Alabama in Huntsville   0.0      0.0        0.0         0
# Alabama State University              1.0      0.0        0.0         0
#
#                                      SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Alabama A & M University                424.0     420.0           0.0
# University of Alabama at Birmingham     570.0     565.0           0.0
# Amridge University                        NaN       NaN           1.0
# University of Alabama in Huntsville     595.0     590.0           0.0
# Alabama State University                425.0     430.0           0.0
#
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  ...  \
# INSTNM                                                                ...
# Alabama A & M University              4206.0      0.0333      0.9353  ...
# University of Alabama at Birmingham  11383.0      0.5922      0.2600  ...
# Amridge University                     291.0      0.2990      0.4192  ...
# University of Alabama in Huntsville   5451.0      0.6988      0.1255  ...
# Alabama State University              4811.0      0.0158      0.9208  ...
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Alabama A & M University                0.0000    0.0059     0.0138    0.0656
# University of Alabama at Birmingham     0.0368    0.0179     0.0100    0.2607
# Amridge University                      0.0000    0.0000     0.2715    0.4536
# University of Alabama in Huntsville     0.0172    0.0332     0.0350    0.2146
# Alabama State University                0.0098    0.0243     0.0137    0.0892
#
#                                      CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University                    1   0.7356    0.8284   0.1049
# University of Alabama at Birmingham         1   0.3460    0.5214   0.2422
# Amridge University                          1   0.6801    0.7795   0.8540
# University of Alabama in Huntsville         1   0.3072    0.4596   0.2640
# Alabama State University                    1   0.7347    0.7554   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
# University of Alabama in Huntsville          45500.0             24097.0
# Alabama State University                     26600.0             33118.5
#
# [5 rows x 24 columns]

# %%
# several columns have binary values (0 or 1) which are also not useful for max values
# create a Boolean Series to find all columns that have two unique values using .nunique
binary_only = college_n.nunique() == 2
binary_only.head()
# Out:
# HBCU          True
# MENONLY       True
# WOMENONLY     True
# RELAFFIL      True
# SATVRMID     False
# dtype: bool

# %%
# use Boolean array to create list of binary columns
binary_cols = binary_only[binary_only].index
binary_cols
# Out:
# Index(['HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL', 'DISTANCEONLY', 'CURROPER'], dtype='object')

# %%
# drop binary columns using .drop method
college_n2 = college_n.drop(columns=binary_cols)
college_n2.head()
# Out:
#                                      SATVRMID  SATMTMID     UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                424.0     420.0   4206.0      0.0333
# University of Alabama at Birmingham     570.0     565.0  11383.0      0.5922
# Amridge University                        NaN       NaN    291.0      0.2990
# University of Alabama in Huntsville     595.0     590.0   5451.0      0.6988
# Alabama State University                425.0     430.0   4811.0      0.0158
#
#                                      UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University                 0.9353     0.0055      0.0019
# University of Alabama at Birmingham      0.2600     0.0283      0.0518
# Amridge University                       0.4192     0.0069      0.0034
# University of Alabama in Huntsville      0.1255     0.0382      0.0376
# Alabama State University                 0.9208     0.0121      0.0019
#
#                                      UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# Alabama A & M University                0.0024     0.0019     0.0000
# University of Alabama at Birmingham     0.0022     0.0007     0.0368
# Amridge University                      0.0000     0.0000     0.0000
# University of Alabama in Huntsville     0.0143     0.0002     0.0172
# Alabama State University                0.0010     0.0006     0.0098
#
#                                      UGDS_NRA  UGDS_UNKN  PPTUG_EF  PCTPELL  \
# INSTNM
# Alabama A & M University               0.0059     0.0138    0.0656   0.7356
# University of Alabama at Birmingham    0.0179     0.0100    0.2607   0.3460
# Amridge University                     0.0000     0.2715    0.4536   0.6801
# University of Alabama in Huntsville    0.0332     0.0350    0.2146   0.3072
# Alabama State University               0.0243     0.0137    0.0892   0.7347
#
#                                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University               0.8284   0.1049          30300.0
# University of Alabama at Birmingham    0.5214   0.2422          39700.0
# Amridge University                     0.7795   0.8540          40100.0
# University of Alabama in Huntsville    0.4596   0.2640          45500.0
# Alabama State University               0.7554   0.1270          26600.0
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                        33888.0
# University of Alabama at Birmingham             21941.5
# Amridge University                              23370.0
# University of Alabama in Huntsville             24097.0
# Alabama State University                        33118.5

# %%
# use the .idxmax method to find the index label of the max value for each col
max_cols = college_n2.idxmax()
max_cols
# Out:
# SATVRMID                             California Institute of Technology
# SATMTMID                             California Institute of Technology
# UGDS                                      University of Phoenix-Arizona
# UGDS_WHITE                       Mr Leon's School of Hair Design-Moscow
# UGDS_BLACK                           Velvatex College of Beauty Culture
# UGDS_HISP                       Thunderbird School of Global Management
# UGDS_ASIAN                          Cosmopolitan Beauty and Tech School
# UGDS_AIAN                             Haskell Indian Nations University
# UGDS_NHPI                                       Palau Community College
# UGDS_2MOR                                                 LIU Brentwood
# UGDS_NRA               California University of Management and Sciences
# UGDS_UNKN             Le Cordon Bleu College of Culinary Arts-San Fr...
# PPTUG_EF                        Thunderbird School of Global Management
# PCTPELL                                        MTI Business College Inc
# PCTFLOAN                                         ABC Beauty College Inc
# UG25ABV                                  Dongguk University-Los Angeles
# MD_EARN_WNE_P10                            Medical College of Wisconsin
# GRAD_DEBT_MDN_SUPP           Southwest University of Visual Arts-Tucson
# dtype: object

# %%
# call the .unique method on the max_cols Series to return an ndarray of
# the index values in college_n2 that has max values
unique_max_cols = max_cols.unique()
unique_max_cols[:5]
# Out:
# array(['California Institute of Technology',
#        'University of Phoenix-Arizona',
#        "Mr Leon's School of Hair Design-Moscow",
#        'Velvatex College of Beauty Culture',
#        'Thunderbird School of Global Management'], dtype=object)

# %%
# use the values of max_cols to select only those rows that have schools w/ a
# max value and then use the .style attribute to highlight these values
college_n2.loc[unique_max_cols].style.highlight_max()
# Out:
# <style type="text/css">
# #T_385a7_row0_col0, #T_385a7_row0_col1, #T_385a7_row1_col2, #T_385a7_row2_col3, #T_385a7_row3_col4, #T_385a7_row4_col5, #T_385a7_row4_col12, #T_385a7_row5_col6, #T_385a7_row6_col7, #T_385a7_row7_col8, #T_385a7_row8_col9, #T_385a7_row9_col10, #T_385a7_row10_col11, #T_385a7_row11_col13, #T_385a7_row11_col14, #T_385a7_row12_col14, #T_385a7_row13_col15, #T_385a7_row14_col16, #T_385a7_row15_col17 {
#   background-color: yellow;
# }
# </style>
# <table id="T_385a7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_385a7_level0_col0" class="col_heading level0 col0" >SATVRMID</th>
#       <th id="T_385a7_level0_col1" class="col_heading level0 col1" >SATMTMID</th>
#       <th id="T_385a7_level0_col2" class="col_heading level0 col2" >UGDS</th>
#       <th id="T_385a7_level0_col3" class="col_heading level0 col3" >UGDS_WHITE</th>
#       <th id="T_385a7_level0_col4" class="col_heading level0 col4" >UGDS_BLACK</th>
#       <th id="T_385a7_level0_col5" class="col_heading level0 col5" >UGDS_HISP</th>
#       <th id="T_385a7_level0_col6" class="col_heading level0 col6" >UGDS_ASIAN</th>
#       <th id="T_385a7_level0_col7" class="col_heading level0 col7" >UGDS_AIAN</th>
#       <th id="T_385a7_level0_col8" class="col_heading level0 col8" >UGDS_NHPI</th>
#       <th id="T_385a7_level0_col9" class="col_heading level0 col9" >UGDS_2MOR</th>
#       <th id="T_385a7_level0_col10" class="col_heading level0 col10" >UGDS_NRA</th>
#       <th id="T_385a7_level0_col11" class="col_heading level0 col11" >UGDS_UNKN</th>
#       <th id="T_385a7_level0_col12" class="col_heading level0 col12" >PPTUG_EF</th>
#       <th id="T_385a7_level0_col13" class="col_heading level0 col13" >PCTPELL</th>
#       <th id="T_385a7_level0_col14" class="col_heading level0 col14" >PCTFLOAN</th>
#       <th id="T_385a7_level0_col15" class="col_heading level0 col15" >UG25ABV</th>
#       <th id="T_385a7_level0_col16" class="col_heading level0 col16" >MD_EARN_WNE_P10</th>
#       <th id="T_385a7_level0_col17" class="col_heading level0 col17" >GRAD_DEBT_MDN_SUPP</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >INSTNM</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_385a7_level0_row0" class="row_heading level0 row0" >California Institute of Technology</th>
#       <td id="T_385a7_row0_col0" class="data row0 col0" >765.000000</td>
#       <td id="T_385a7_row0_col1" class="data row0 col1" >785.000000</td>
#       <td id="T_385a7_row0_col2" class="data row0 col2" >983.000000</td>
#       <td id="T_385a7_row0_col3" class="data row0 col3" >0.278700</td>
#       <td id="T_385a7_row0_col4" class="data row0 col4" >0.015300</td>
#       <td id="T_385a7_row0_col5" class="data row0 col5" >0.122100</td>
#       <td id="T_385a7_row0_col6" class="data row0 col6" >0.438500</td>
#       <td id="T_385a7_row0_col7" class="data row0 col7" >0.001000</td>
#       <td id="T_385a7_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_385a7_row0_col9" class="data row0 col9" >0.057000</td>
#       <td id="T_385a7_row0_col10" class="data row0 col10" >0.087500</td>
#       <td id="T_385a7_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_385a7_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_385a7_row0_col13" class="data row0 col13" >0.112600</td>
#       <td id="T_385a7_row0_col14" class="data row0 col14" >0.230300</td>
#       <td id="T_385a7_row0_col15" class="data row0 col15" >0.008200</td>
#       <td id="T_385a7_row0_col16" class="data row0 col16" >77800.000000</td>
#       <td id="T_385a7_row0_col17" class="data row0 col17" >11812.500000</td>
#     </tr>
#     <tr>
#       <th id="T_385a7_level0_row1" class="row_heading level0 row1" >University of Phoenix-Arizona</th>
#       <td id="T_385a7_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_385a7_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_385a7_row1_col2" class="data row1 col2" >151558.000000</td>
#       <td id="T_385a7_row1_col3" class="data row1 col3" >0.309800</td>
#       <td id="T_385a7_row1_col4" class="data row1 col4" >0.155500</td>
#       <td id="T_385a7_row1_col5" class="data row1 col5" >0.076000</td>
#       <td id="T_385a7_row1_col6" class="data row1 col6" >0.008200</td>
#       <td id="T_385a7_row1_col7" class="data row1 col7" >0.004200</td>
#       <td id="T_385a7_row1_col8" class="data row1 col8" >0.005000</td>
#       <td id="T_385a7_row1_col9" class="data row1 col9" >0.113100</td>
#       <td id="T_385a7_row1_col10" class="data row1 col10" >0.013100</td>
#       <td id="T_385a7_row1_col11" class="data row1 col11" >0.315200</td>
#       <td id="T_385a7_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_385a7_row1_col13" class="data row1 col13" >0.600900</td>
#       <td id="T_385a7_row1_col14" class="data row1 col14" >0.592000</td>
#       <td id="T_385a7_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_385a7_row1_col16" class="data row1 col16" >nan</td>
#       <td id="T_385a7_row1_col17" class="data row1 col17" >33000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_385a7_level0_row2" class="row_heading level0 row2" >Mr Leon's School of Hair Design-Moscow</th>
#       <td id="T_385a7_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_385a7_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_385a7_row2_col2" class="data row2 col2" >16.000000</td>
#       <td id="T_385a7_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_385a7_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_385a7_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_385a7_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_385a7_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_385a7_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_385a7_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_385a7_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_385a7_row2_col11" class="data row2 col11" >0.000000</td>
#       <td id="T_385a7_row2_col12" class="data row2 col12" >0.000000</td>
#       <td id="T_385a7_row2_col13" class="data row2 col13" >0.625000</td>
#       <td id="T_385a7_row2_col14" class="data row2 col14" >0.625000</td>
#       <td id="T_385a7_row2_col15" class="data row2 col15" >0.200000</td>
#       <td id="T_385a7_row2_col16" class="data row2 col16" >nan</td>
#       <td id="T_385a7_row2_col17" class="data row2 col17" >15710.000000</td>
#     </tr>
#     <tr>
#       <th id="T_385a7_level0_row3" class="row_heading level0 row3" >Velvatex College of Beauty Culture</th>
#       <td id="T_385a7_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_385a7_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_385a7_row3_col2" class="data row3 col2" >25.000000</td>
#       <td id="T_385a7_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_385a7_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_385a7_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_385a7_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_385a7_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_385a7_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_385a7_row3_col9" class="data row3 col9" >0.

# %%
# display the max column values
# refactor to make easier to read
def remove_binary_cols(df):
  binary_only = df.nunique() == 2
  cols = binary_only[binary_only].index.tolist()
  return df.drop(columns=cols)

def select_rows_with_max_cols(df):
  max_cols = df.idxmax()
  unique = max_cols.unique()
  return df.loc[unique]

(college.assign(MD_EARN_WNE_P10=pd.to_numeric(college.MD_EARN_WNE_P10, errors="coerce"),
                GRAD_DEBT_MDN_SUPP=pd.to_numeric(college.GRAD_DEBT_MDN_SUPP, errors="coerce"),
                ).select_dtypes("number").pipe(remove_binary_cols).pipe(select_rows_with_max_cols))
# Out:
#                                                     SATVRMID  SATMTMID  \
# INSTNM
# California Institute of Technology                     765.0     785.0
# University of Phoenix-Arizona                            NaN       NaN
# Mr Leon's School of Hair Design-Moscow                   NaN       NaN
# Velvatex College of Beauty Culture                       NaN       NaN
# Thunderbird School of Global Management                  NaN       NaN
# Cosmopolitan Beauty and Tech School                      NaN       NaN
# Haskell Indian Nations University                      430.0     440.0
# Palau Community College                                  NaN       NaN
# LIU Brentwood                                            NaN       NaN
# California University of Management and Sciences         NaN       NaN
# Le Cordon Bleu College of Culinary Arts-San Fra...       NaN       NaN
# MTI Business College Inc                                 NaN       NaN
# ABC Beauty College Inc                                   NaN       NaN
# Dongguk University-Los Angeles                           NaN       NaN
# Medical College of Wisconsin                             NaN       NaN
# Southwest University of Visual Arts-Tucson               NaN       NaN
#
#                                                         UGDS  UGDS_WHITE  \
# INSTNM
# California Institute of Technology                     983.0      0.2787
# University of Phoenix-Arizona                       151558.0      0.3098
# Mr Leon's School of Hair Design-Moscow                  16.0      1.0000
# Velvatex College of Beauty Culture                      25.0      0.0000
# Thunderbird School of Global Management                  1.0      0.0000
# Cosmopolitan Beauty and Tech School                    110.0      0.0091
# Haskell Indian Nations University                      805.0      0.0000
# Palau Community College                                602.0      0.0000
# LIU Brentwood                                           15.0      0.0000
# California University of Management and Sciences        98.0      0.0102
# Le Cordon Bleu College of Culinary Arts-San Fra...     442.0      0.0317
# MTI Business College Inc                               146.0      0.2397
# ABC Beauty College Inc                                  38.0      0.2895
# Dongguk University-Los Angeles                          20.0      0.3500
# Medical College of Wisconsin                             NaN         NaN
# Southwest University of Visual Arts-Tucson             161.0      0.4534
#
#                                                     UGDS_BLACK  UGDS_HISP  \
# INSTNM
# California Institute of Technology                      0.0153     0.1221
# University of Phoenix-Arizona                           0.1555     0.0760
# Mr Leon's School of Hair Design-Moscow                  0.0000     0.0000
# Velvatex College of Beauty Culture                      1.0000     0.0000
# Thunderbird School of Global Management                 0.0000     1.0000
# Cosmopolitan Beauty and Tech School                     0.0000     0.0182
# Haskell Indian Nations University                       0.0000     0.0000
# Palau Community College                                 0.0017     0.0000
# LIU Brentwood                                           0.1333     0.2667
# California University of Management and Sciences        0.0204     0.0000
# Le Cordon Bleu College of Culinary Arts-San Fra...      0.0090     0.0113
# MTI Business College Inc                                0.5137     0.1438
# ABC Beauty College Inc                                  0.6579     0.0526
# Dongguk University-Los Angeles                          0.0000     0.1500
# Medical College of Wisconsin                               NaN        NaN
# Southwest University of Visual Arts-Tucson              0.0435     0.3168
#
#                                                     UGDS_ASIAN  UGDS_AIAN  \
# INSTNM
# California Institute of Technology                      0.4385     0.0010
# University of Phoenix-Arizona                           0.0082     0.0042
# Mr Leon's School of Hair Design-Moscow                  0.0000     0.0000
# Velvatex College of Beauty Culture                      0.0000     0.0000
# Thunderbird School of Global Management                 0.0000     0.0000
# Cosmopolitan Beauty and Tech School                     0.9727     0.0000
# Haskell Indian Nations University                       0.0000     1.0000
# Palau Community College                                 0.0000     0.0000
# LIU Brentwood                                           0.0000     0.0000
# California University of Management and Sciences        0.0408     0.0000
# Le Cordon Bleu College of Culinary Arts-San Fra...      0.0271     0.0045
# MTI Business College Inc                                0.0479     0.0342
# ABC Beauty College Inc                                  0.0000     0.0000
# Dongguk University-Los Angeles                          0.5000     0.0000
# Medical College of Wisconsin                               NaN        NaN
# Southwest University of Visual Arts-Tucson              0.0062     0.0311
#
#                                                     UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# California Institute of Technology                     0.0000     0.0570
# University of Phoenix-Arizona                          0.0050     0.1131
# Mr Leon's School of Hair Design-Moscow                 0.0000     0.0000
# Velvatex College of Beauty Culture                     0.0000     0.0000
# Thunderbird School of Global Management                0.0000     0.0000
# Cosmopolitan Beauty and Tech School                    0.0000     0.0000
# Haskell Indian Nations University                      0.0000     0.0000
# Palau Community College                                0.9983     0.0000
# LIU Brentwood                                          0.0000     0.5333
# California University of Management and Sciences       0.0000     0.0000
# Le Cordon Bleu College of Culinary Arts-San Fra...     0.0023     0.0113
# MTI Business College Inc                               0.0205     0.0000
# ABC Beauty College Inc                                 0.0000     0.0000
# Dongguk University-Los Angeles                         0.0000     0.0000
# Medical College of Wisconsin                              NaN        NaN
# Southwest University of Visual Arts-Tucson             0.0000     0.0000
#
#                                                     UGDS_NRA  UGDS_UNKN  \
# INSTNM
# California Institute of Technology                    0.0875     0.0000
# University of Phoenix-Arizona                         0.0131     0.3152
# Mr Leon's School of Hair Design-Moscow                0.0000     0.0000
# Velvatex College of Beauty Culture                    0.0000     0.0000
# Thunderbird School of Global Management               0.0000     0.0000
# Cosmopolitan Beauty and Tech School                   0.0000     0.0000
# Haskell Indian Nations University                     0.0000     0.0000
# Palau Community College                               0.0000     0.0000
# LIU Brentwood                                         0.0000     0.0667
# California University of Management and Sciences      0.9286     0.0000
# Le Cordon Bleu College of Culinary Arts-San Fra...    0.0000     0.9027
# MTI Business College Inc                              0.0000     0.0000
# ABC Beauty College Inc                                0.0000     0.0000
# Dongguk University-Los Angeles                        0.0000     0.0000
# Medical College of Wisconsin                             NaN        NaN
# Southwest University of Visual Arts-Tucson            0.0000     0.1491
#
#                                                     PPTUG_EF  PCTPELL  \
# INSTNM
# California Institute of Technology                    0.0000   0.1126
# University of Phoenix-Arizona                         0.0000   0.6009
# Mr Leon's School of Hair Design-Moscow                0.0000   0.6250
# Velvatex College of Beauty Culture                    0.2000   0.7692
# Thunderbird School of Global Management               1.0000   0.0000
# Cosmopolitan Beauty and Tech School                   0.3182   0.7761
# Haskell Indian Nations University                     0.0224   0.8396
# Palau Community College                               0.3887   0.8560
# LIU Brentwood                                         0.4000   0.5652
# California University of Management and Sciences      0.0000   0.0926
# Le Cordon Bleu College of Culinary Arts-San Fra...    0.0000   0.3722
# MTI Business College Inc                              0.0000   1.0000
# ABC Beauty College Inc                                0.2105   0.9815
# Dongguk University-Los Angeles                           NaN      NaN
# Medical College of Wisconsin                             NaN      NaN
# Southwest University of Visual Arts-Tucson            0.2795   0.4469
#
#                                                     PCTFLOAN  UG25ABV  \
# INSTNM
# California Institute of Technology                    0.2303   0.0082
# University of Phoenix-Arizona                         0.5920      NaN
# Mr Leon's School of Hair Design-Moscow                0.6250   0.2000
# Velvatex College of Beauty Culture                    0.0000   0.5200
# Thunderbird School of Global Management               0.0000   0.0000
# Cosmopolitan Beauty and Tech School                   0.1244   0.9545
# Haskell Indian Nations University                     0.0000   0.2089
# Palau Community College                               0.0000   0.2616
# LIU Brentwood                                         0.7826   0.7826
# California University of Management and Sciences      0.0556   0.6852
# Le Cordon Bleu College of Culinary Arts-San Fra...    0.5358   0.5440
# MTI Business College Inc                              1.0000   0.3986
# ABC Beauty College Inc                                1.0000   0.4688
# Dongguk University-Los Angeles                           NaN   1.0000
# Medical College of Wisconsin                             NaN      NaN
# Southwest University of Visual Arts-Tucson            0.4292   0.8657
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# California Institute of Technology                          77800.0
# University of Phoenix-Arizona                                   NaN
# Mr Leon's School of Hair Design-Moscow                          NaN
# Velvatex College of Beauty Culture                              NaN
# Thunderbird School of Global Management                    118900.0
# Cosmopolitan Beauty and Tech School                             NaN
# Haskell Indian Nations University                           22800.0
# Palau Community College                                     24700.0
# LIU Brentwood                                               44600.0
# California University of Management and Sciences                NaN
# Le Cordon Bleu College of Culinary Arts-San Fra...          34000.0
# MTI Business College Inc                                    23000.0
# ABC Beauty College Inc                                          NaN
# Dongguk University-Los Angeles                                  NaN
# Medical College of Wisconsin                               233100.0
# Southwest University of Visual Arts-Tucson                  27200.0
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# California Institute of Technology                             11812.5
# University of Phoenix-Arizona                                  33000.0
# Mr Leon's School of Hair Design-Moscow                         15710.0
# Velvatex College of Beauty Culture                                 NaN
# Thunderbird School of Global Management                            NaN
# Cosmopolitan Beauty and Tech School                                NaN
# Haskell Indian Nations University                                  NaN
# Palau Community College                                            NaN
# LIU Brentwood                                                  25499.0
# California University of Management and Sciences                   NaN
# Le Cordon Bleu College of Culinary Arts-San Fra...             12931.0
# MTI Business College Inc                                        9500.0
# ABC Beauty College Inc                                         16500.0
# Dongguk University-Los Angeles                                     NaN
# Medical College of Wisconsin                                       NaN
# Southwest University of Visual Arts-Tucson                     49750.0

# %%
# by default .highlight_max method highlights the max value of each col
# we can use the axis parameter to highlight the max value of each row instead
college_ugds = college.filter(like="UGDS_").head()
college_ugds.style.highlight_max(axis="columns")
# Out:
# <style type="text/css">
# #T_c2077_row0_col1, #T_c2077_row1_col0, #T_c2077_row2_col1, #T_c2077_row3_col0, #T_c2077_row4_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c2077" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2077_level0_col0" class="col_heading level0 col0" >UGDS_WHITE</th>
#       <th id="T_c2077_level0_col1" class="col_heading level0 col1" >UGDS_BLACK</th>
#       <th id="T_c2077_level0_col2" class="col_heading level0 col2" >UGDS_HISP</th>
#       <th id="T_c2077_level0_col3" class="col_heading level0 col3" >UGDS_ASIAN</th>
#       <th id="T_c2077_level0_col4" class="col_heading level0 col4" >UGDS_AIAN</th>
#       <th id="T_c2077_level0_col5" class="col_heading level0 col5" >UGDS_NHPI</th>
#       <th id="T_c2077_level0_col6" class="col_heading level0 col6" >UGDS_2MOR</th>
#       <th id="T_c2077_level0_col7" class="col_heading level0 col7" >UGDS_NRA</th>
#       <th id="T_c2077_level0_col8" class="col_heading level0 col8" >UGDS_UNKN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >INSTNM</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2077_level0_row0" class="row_heading level0 row0" >Alabama A & M University</th>
#       <td id="T_c2077_row0_col0" class="data row0 col0" >0.033300</td>
#       <td id="T_c2077_row0_col1" class="data row0 col1" >0.935300</td>
#       <td id="T_c2077_row0_col2" class="data row0 col2" >0.005500</td>
#       <td id="T_c2077_row0_col3" class="data row0 col3" >0.001900</td>
#       <td id="T_c2077_row0_col4" class="data row0 col4" >0.002400</td>
#       <td id="T_c2077_row0_col5" class="data row0 col5" >0.001900</td>
#       <td id="T_c2077_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_c2077_row0_col7" class="data row0 col7" >0.005900</td>
#       <td id="T_c2077_row0_col8" class="data row0 col8" >0.013800</td>
#     </tr>
#     <tr>
#       <th id="T_c2077_level0_row1" class="row_heading level0 row1" >University of Alabama at Birmingham</th>
#       <td id="T_c2077_row1_col0" class="data row1 col0" >0.592200</td>
#       <td id="T_c2077_row1_col1" class="data row1 col1" >0.260000</td>
#       <td id="T_c2077_row1_col2" class="data row1 col2" >0.028300</td>
#       <td id="T_c2077_row1_col3" class="data row1 col3" >0.051800</td>
#       <td id="T_c2077_row1_col4" class="data row1 col4" >0.002200</td>
#       <td id="T_c2077_row1_col5" class="data row1 col5" >0.000700</td>
#       <td id="T_c2077_row1_col6" class="data row1 col6" >0.036800</td>
#       <td id="T_c2077_row1_col7" class="data row1 col7" >0.017900</td>
#       <td id="T_c2077_row1_col8" class="data row1 col8" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_c2077_level0_row2" class="row_heading level0 row2" >Amridge University</th>
#       <td id="T_c2077_row2_col0" class="data row2 col0" >0.299000</td>
#       <td id="T_c2077_row2_col1" class="data row2 col1" >0.419200</td>
#       <td id="T_c2077_row2_col2" class="data row2 col2" >0.006900</td>
#       <td id="T_c2077_row2_col3" class="data row2 col3" >0.003400</td>
#       <td id="T_c2077_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_c2077_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_c2077_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_c2077_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_c2077_row2_col8" class="data row2 col8" >0.271500</td>
#     </tr>
#     <tr>
#       <th id="T_c2077_level0_row3" class="row_heading level0 row3" >University of Alabama in Huntsville</th>
#       <td id="T_c2077_row3_col0" class="data row3 col0" >0.698800</td>
#       <td id="T_c2077_row3_col1" class="data row3 col1" >0.125500</td>
#       <td id="T_c2077_row3_col2" class="data row3 col2" >0.038200</td>
#       <td id="T_c2077_row3_col3" class="data row3 col3" >0.037600</td>
#       <td id="T_c2077_row3_col4" class="data row3 col4" >0.014300</td>
#       <td id="T_c2077_row3_col5" class="data row3 col5" >0.000200</td>
#       <td id="T_c2077_row3_col6" class="data row3 col6" >0.017200</td>
#       <td id="T_c2077_row3_col7" class="data row3 col7" >0.033200</td>
#       <td id="T_c2077_row3_col8" class="data row3 col8" >0.035000</td>
#     </tr>
#     <tr>
#       <th id="T_c2077_level0_row4" class="row_heading level0 row4" >Alabama State University</th>
#       <td id="T_c2077_row4_col0" class="data row4 col0" >0.015800</td>
#       <td id="T_c2077_row4_col1" class="data row4 col1" >0.920800</td>
#       <td id="T_c2077_row4_col2" class="data row4 col2" >0.012100</td>
#       <td id="T_c2077_row4_col3" class="data row4 col3" >0.001900</td>
#       <td id="T_c2077_row4_col4" class="data row4 col4" >0.001000</td>
#       <td id="T_c2077_row4_col5" class="data row4 col5" >0.000600</td>
#       <td id="T_c2077_row4_col6" class="data row4 col6" >0.009800</td>
#       <td id="T_c2077_row4_col7" class="data row4 col7" >0.024300</td>
#       <td id="T_c2077_row4_col8" class="data row4 col8" >0.013700</td>
#     </tr>
#   </tbody>
# </table>
