# %% [markdown]
# <a href="https://colab.research.google.com/github/bdunn20/book_code/blob/main/pandas_1.X_cookbook/Ch_4_Beginning_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA: metadata & descriptive statistics
#
# [Link to data - Github](https://github.com/PacktPublishing/Pandas-Cookbook-Second-Edition/tree/master/data)

# %% [markdown]
# ### Packages & Data

# %%
import pandas as pd
import numpy as np
college = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/college.csv?_sm_au_=iVV7TJDkR4JN7kQfBQvGvK7jj80tt')
college.sample(random_state=42)
# Out:
#                     INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 3649  Career Point College  San Antonio     TX   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 3649         0       NaN       NaN           0.0  ...        0.0       0.0
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 3649        0.0       0.0         1   0.9172    0.9172    0.697
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3649            20700               14977
#
# [1 rows x 27 columns]

# %%
college.shape
# Out:
# (7535, 27)

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   INSTNM              7535 non-null   object
#  1   CITY                7535 non-null   object
#  2   STABBR              7535 non-null   object
#  3   HBCU                7164 non-null   float64
#  4   MENONLY             7164 non-null   float64
#  5   WOMENONLY           7164 non-null   float64
#  6   RELAFFIL            7535 non-null   int64
#  7   SATVRMID            1185 non-null   float64
#  8   SATMTMID            1196 non-null   float64
#  9   DISTANCEONLY        7164 non-null   float64
#  10  UGDS                6874 non-null   float64
#  11  UGDS_WHITE          6874 non-null   float64
#  12  UGDS_BLACK          6874 non-null   float64
#  13  UGDS_HISP           6874 non-null   float64
#  14  UGDS_ASIAN          6874 non-null   float64
# ...

# %%
# summary stats for numerical cols
# transpose for readability
college.describe(include=[np.number]).T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# ...

# %%
# summary stats for descriptive cols
college.describe(include=[object]).T
# Out:
#                    count unique                       top  freq
# INSTNM              7535   7535  Alabama A & M University     1
# CITY                7535   2514                  New York    87
# STABBR              7535     59                        CA   773
# MD_EARN_WNE_P10     6413    598         PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038         PrivacySuppressed  1510

# %%
# specify quantiles from .describe
college.describe(include=[np.number], percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.99]).T
# Out:
#                count         mean          std    min          1%          5%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.000000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.000000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.000000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.000000
# SATVRMID      1185.0   522.819409    68.578862  290.0  390.000000  430.000000
# SATMTMID      1196.0   530.765050    73.469767  310.0  395.000000  430.000000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.000000
# UGDS          6874.0  2356.837940  5474.275871    0.0   14.000000   31.650000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.000000    0.013265
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.000000    0.000000
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.000000    0.000000
# ...

# %% [markdown]
# ### Data Dictionary

# %%
# load data dictionary from github
college_data_dict = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/college_data_dictionary.csv?_sm_au_=iVV7TJDkR4JN7kQfBQvGvK7jj80tt')

# %%
college_data_dict
# Out:
#            column_name                                        description
# 0               INSTNM                                   Institution Name
# 1                 CITY                                      City Location
# 2               STABBR                                 State Abbreviation
# 3                 HBCU           Historically Black College or University
# 4              MENONLY                                       0/1 Men Only
# 5            WOMENONLY                                     0/1 Women only
# 6             RELAFFIL                          0/1 Religious Affiliation
# 7             SATVRMID                                  SAT Verbal Median
# 8             SATMTMID                                    SAT Math Median
# 9         DISTANCEONLY                            Distance Education Only
# 10                UGDS                           Undergraduate Enrollment
# 11          UGDS_WHITE                            Percent Undergrad White
# ...

# %% [markdown]
# ### Reducing memory usage by changing data types

# %%
diff_cols = ["RELAFFIL", "SATMTMID", "CURROPER", "INSTNM", "STABBR"]

col2 = college.loc[:, diff_cols]

col2.head()
# Out:
#    RELAFFIL  SATMTMID  CURROPER                               INSTNM STABBR
# 0         0     420.0         1             Alabama A & M University     AL
# 1         0     565.0         1  University of Alabama at Birmingham     AL
# 2         1       NaN         1                   Amridge University     AL
# 3         0     590.0         1  University of Alabama in Huntsville     AL
# 4         0     430.0         1             Alabama State University     AL

# %%
col2.dtypes
# Out:
# RELAFFIL      int64
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
original_mem = col2.memory_usage(deep=True)
original_mem
# Out:
# Index          128
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
# no need to use 64 bits for RELAFFIL as it contains only 0 or 1
# convert to 8-bit (1 byte) integer using .astype method
col2["RELAFFIL"]  = col2["RELAFFIL"].astype(np.int8)
col2.dtypes
# Out:
# RELAFFIL       int8
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
col2.memory_usage(deep=True)
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
# change object data types to categorical
# if they have reasonably low cardinality (unique values)

# check unique values for each object col
col2.select_dtypes(include=["object"]).nunique()
# Out:
# INSTNM    7535
# STABBR      59
# dtype: int64

# %%
# STABBR is the only good candidate
col2["STABBR"] = col2["STABBR"].astype("category")
col2.dtypes
# Out:
# RELAFFIL        int8
# SATMTMID     float64
# CURROPER       int64
# INSTNM        object
# STABBR      category
# dtype: object

# %%
new_mem = col2.memory_usage(deep=True)
new_mem
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660699
# STABBR       13120
# dtype: int64

# %%
# compare original memory usage to updated memory usage
new_mem / original_mem
# Out:
# Index       1.000000
# RELAFFIL    0.125000
# SATMTMID    1.000000
# CURROPER    1.000000
# INSTNM      1.000695
# STABBR      0.029512
# dtype: float64

# %% [markdown]
# ### Selecting the smallest of the largest

# %%
movie = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/movie.csv')
# select columns
movie2 = movie[["movie_title", "imdb_score", "budget"]]
movie2.head()
# Out:
#                                   movie_title  imdb_score       budget
# 0                                      Avatar         7.9  237000000.0
# 1    Pirates of the Caribbean: At World's End         7.1  300000000.0
# 2                                     Spectre         6.8  245000000.0
# 3                       The Dark Knight Rises         8.5  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens         7.1          NaN

# %%
# select top 100 movies using .nlargest
movie2.nlargest(100, "imdb_score").head()
# Out:
#                    movie_title  imdb_score      budget
# 2725          Towering Inferno         9.5         NaN
# 1920  The Shawshank Redemption         9.3  25000000.0
# 3402             The Godfather         9.2   6000000.0
# 2779                   Dekalog         9.1         NaN
# 4312      Kickboxer: Vengeance         9.1  17000000.0

# %%
# chain the .nsmallest method to return the 5 lowest budget films among top 100 imdb_score
movie2.nlargest(100, "imdb_score").nsmallest(5, "budget")
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %% [markdown]
# ### Selecting the largest of each group by sorting

# %%
movie3 = movie[["movie_title", "title_year", "imdb_score"]]
# use .sort_values to sort the df by title_year
movie3.sort_values("title_year", ascending=True).head()
# Out:
#                                            movie_title  title_year  imdb_score
# 4695  Intolerance: Love's Struggle Throughout the Ages      1916.0         8.0
# 4833                    Over the Hill to the Poorhouse      1920.0         4.8
# 4767                                    The Big Parade      1925.0         8.3
# 2694                                        Metropolis      1927.0         8.3
# 4697                               The Broadway Melody      1929.0         6.3

# %%
# sort by multiple columns using a list
movie3.sort_values(["title_year", "imdb_score"], ascending=False)
# Out:
#                       movie_title  title_year  imdb_score
# 4312         Kickboxer: Vengeance      2016.0         9.1
# 4277  A Beginner's Guide to Snuff      2016.0         8.7
# 3798                      Airlift      2016.0         8.5
# 27     Captain America: Civil War      2016.0         8.2
# 98            Godzilla Resurgence      2016.0         8.2
# ...                           ...         ...         ...
# 1391                    Rush Hour         NaN         5.8
# 4031                     Creature         NaN         5.0
# 2165              Meet the Browns         NaN         3.5
# 3246   The Bold and the Beautiful         NaN         3.5
# 2119                 The Bachelor         NaN         2.9
#
# [4916 rows x 3 columns]

# %%
# use .drop_duplicates to keep only the first row of every year
movie3.sort_values(["title_year", "imdb_score"], ascending=False).drop_duplicates(subset="title_year")
# Out:
#                                            movie_title  title_year  imdb_score
# 4312                              Kickboxer: Vengeance      2016.0         9.1
# 3745                                   Running Forever      2015.0         8.6
# 4369                            Queen of the Mountains      2014.0         8.7
# 3935           Batman: The Dark Knight Returns, Part 2      2013.0         8.4
# 3                                The Dark Knight Rises      2012.0         8.5
# ...                                                ...         ...         ...
# 2694                                        Metropolis      1927.0         8.3
# 4767                                    The Big Parade      1925.0         8.3
# 4833                    Over the Hill to the Poorhouse      1920.0         4.8
# 4695  Intolerance: Love's Struggle Throughout the Ages      1916.0         8.0
# 2725                                  Towering Inferno         NaN         9.5
#
# [92 rows x 3 columns]

# %%
# sort on column ascending while simultaneously sorting another column descending
movie4 = movie[["movie_title", "title_year", "content_rating", "budget"]]
movie4.sort_values(["title_year", "content_rating", "budget"], ascending=[False, False, True])\
                  .drop_duplicates(subset=["title_year", "content_rating"])
# Out:
#                          movie_title  title_year content_rating      budget
# 4026                       Compadres      2016.0              R   3000000.0
# 4658             Fight to the Finish      2016.0          PG-13    150000.0
# 4661                      Rodeo Girl      2016.0             PG    500000.0
# 3252                     The Wailing      2016.0      Not Rated         NaN
# 4659  Alleluia! The Devil's Carnival      2016.0            NaN    500000.0
# ...                              ...         ...            ...         ...
# 2558                      Lilyhammer         NaN          TV-MA  34000000.0
# 807       Sabrina, the Teenage Witch         NaN           TV-G   3000000.0
# 848                    Stargate SG-1         NaN          TV-14   1400000.0
# 2436                          Carlos         NaN      Not Rated         NaN
# 2119                    The Bachelor         NaN            NaN   3000000.0
#
# [359 rows x 4 columns]

# %% [markdown]
# ### Calculating a trailing stop order price
#
# *stop order* - an order placed by an investor to buy or sell a stock that executes whenever the market price reaches a certain point. Useful to prevent huge losses and protect gains.
#
# *trailing stop order* - continually modify the sale price of the stop order a set % below the current market value. Never moves down and is always tied to the maximum value since the time of purchase.

# %%
! pip install pandas-datareader
! pip install requests_cache

# %%
import datetime
import pandas_datareader.data as web
import requests_cache

# %%
! pip install yahoo_fin

# %%
import yahoo_fin.stock_info as si

# %%
session = requests_cache.CachedSession(cache_name="cache", backend="sqlite",
                                       expire_after=datetime.timedelta(days=90))
session.params["crumb"] = si.get_crumb()

tsla = web.DataReader("tsla", data_source="yahoo", start="2017-1-1", session=session,)
tsla.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-41c29749e3fe> in <cell line: 3>()
#       1 session = requests_cache.CachedSession(cache_name="cache", backend="sqlite",
#       2                                        expire_after=datetime.timedelta(days=90))
# ----> 3 session.params["crumb"] = si.get_crumb()
#       4
#       5 tsla = web.DataReader("tsla", data_source="yahoo", start="2017-1-1", session=session,)
#
# AttributeError: module 'yahoo_fin.stock_info' has no attribute 'get_crumb'
