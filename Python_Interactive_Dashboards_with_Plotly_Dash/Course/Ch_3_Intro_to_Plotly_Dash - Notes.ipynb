# %% [markdown]
# ![image.png](attachment:7ed5efaf-cf39-4170-8e40-05c15de365d5.png)

# %% [markdown]
# ![image.png](attachment:d709d216-f768-467c-8e52-e765ed0179d5.png)

# %% [markdown]
# ![image.png](attachment:4951fb43-9652-46fe-9956-324f9403b1ee.png)

# %% [markdown]
# ![image.png](attachment:32e5c4c8-b67a-4d9c-b595-971e612f3911.png)

# %% [markdown]
# ![image.png](attachment:298e9107-5edc-41cc-80c7-31e902384d05.png)

# %% [markdown]
# ### Creating your first dashboard

# %% [markdown]
# ![image.png](attachment:3380796d-72ae-4d25-823c-77f7bfc648eb.png)
