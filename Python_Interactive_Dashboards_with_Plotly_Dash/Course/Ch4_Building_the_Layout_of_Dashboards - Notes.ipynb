# %% [markdown]
# ### HTML components overview

# %% [markdown]
# ![image.png](attachment:fe03856e-aff4-4415-b7a9-6141a5359121.png)

# %% [markdown]
# ![image.png](attachment:6a4cfa60-604e-4665-9b05-6821ba4a5f7e.png)

# %% [markdown]
# ![image.png](attachment:3f6755a3-30dc-4fe6-a520-a4e090295ec8.png)

# %% [markdown]
# ![image.png](attachment:b8e563d2-d60a-4ac8-a6b1-d894edc40a01.png)
#
# *note the first letter is capitalized: html.H1, html.Div*

# %% [markdown]
# ![image.png](attachment:35587208-108d-48ae-bc79-1317f8678b41.png)
#
# This is the dashboard we will be creating.

# %% [markdown]
# ![image.png](attachment:a5d0b050-4cb7-4f6a-871f-ab82bf16ccf8.png)

# %% [markdown]
# ![image.png](attachment:200157c4-169a-486f-9ec8-69c92988b179.png)

# %% [markdown]
# ### Core Components Overview

# %% [markdown]
# ![image.png](attachment:af3a89a5-d2b7-403a-b4c3-0e7cf35cff37.png)

# %% [markdown]
# ![image.png](attachment:58222360-de92-45a1-8d76-a71ef7ae84dd.png)

# %% [markdown]
# ![image.png](attachment:955fd4e5-a7af-4cd7-b462-6b214be5dc36.png)

# %% [markdown]
# ![image.png](attachment:d8cdde6c-7613-4518-84a2-e81b343b6763.png)

# %% [markdown]
# ![image.png](attachment:53ce524a-4eb7-46af-aa4d-211303e43e0e.png)
