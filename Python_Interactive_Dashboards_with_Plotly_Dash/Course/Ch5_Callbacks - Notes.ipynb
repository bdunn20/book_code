# %% [markdown]
# ### Introduction to Callbacks

# %% [markdown]
# ![image.png](attachment:40cdb9ab-4306-4eab-8304-1bb9986bce7f.png)

# %% [markdown]
# ![image.png](attachment:2b385b8a-095a-4dc3-abbd-d43c8d1b8445.png)

# %% [markdown]
# ![image.png](attachment:d902b4e9-b4c6-4b5c-a0d5-c0fed8fdf4c2.png)

# %% [markdown]
# ![image.png](attachment:d0446fbc-08ad-4105-86d4-32e2a386e514.png)

# %% [markdown]
# More details about decorators at the link: ![image.png](attachment:b28a1fe8-0cc8-4141-8185-e1e4374884b4.png)

# %% [markdown]
# ![image.png](attachment:ecf3efa6-67bc-4f71-969c-13e9deabc144.png)

# %% [markdown]
# ![image.png](attachment:450eb610-6fd9-4623-9b6b-4706b3cf1f27.png)

# %% [markdown]
# ### Building Callbacks w/ a Single Input & Output
