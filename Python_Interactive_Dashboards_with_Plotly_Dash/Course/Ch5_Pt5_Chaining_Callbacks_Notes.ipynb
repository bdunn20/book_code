# %% [markdown]
# # Chaining Callbacks' Inputs & Outputs

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The chained output may only be one of multiple inputs.

# %% [markdown]
# The countries available in the dropdown are chained to the region selected in the radio buttons:
# ![image.png](attachment:image.png)
